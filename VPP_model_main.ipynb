# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
import VPP_model_customer as customer
import VPP_model_household as household
import VPP_model_NEM as nem
